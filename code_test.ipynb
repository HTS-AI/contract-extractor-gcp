# %%
import pandas as pd

df = pd.read_excel("contract_extractions.xlsx")

# %%
df.columns
# Out:
# Index(['Extracted At', 'Document Name', 'Document Type', 'Party Names',
#        'Start Date', 'Due Date', 'Amount', 'Currency', 'Frequency',
#        'Account Type (Head)', 'ID', 'Risk Score'],
#       dtype='object')

# %%
df
# Out:
#              Extracted At           Document Name Document Type  \
# 0 2025-12-02 15:46:22.907  Agreement_Sep 2020.pdf         LEASE
# 1 2025-12-02 15:51:04.967  Agreement_Sep 2020.pdf         LEASE
#
#                                          Party Names  Start Date  Due Date  \
# 0  Dr. ABBAS HYDERI, HYPERTHINK SYSTEMS PRIVATE L...  2020-09-25       NaN
# 1  Dr. ABBAS HYDERI, HYPERTHINK SYSTEMS PRIVATE L...  2020-09-25       NaN
#
#    Amount Currency Frequency   Account Type (Head)  \
# 0   55000      INR   Monthly  Lease/Rental Expense
# 1   55000      INR   Monthly  Lease/Rental Expense
#
#                                                   ID    Risk Score
# 0  PAN: AJPA4931H; CIN: U72400TG2009PTC062852; Ce...  20/100 (Low)
# 1  PAN: AJPA4931H; CIN: U72400TG2009PTC062852; Ce...  20/100 (Low)
